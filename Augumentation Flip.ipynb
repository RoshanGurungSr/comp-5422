# %% [markdown]
# #### **Data Augmentation using Horizontal Flip**

# %%
import os
import Augmentor

# %%
# Average image file per object = 1350
def augument_horizontal_flip(data_dir, label, out_dir, num_transformation=1):
    data_fp = os.path.join(data_dir, label)
    out_fp = os.path.join(out_dir, label)
    
    aug_pipeline = Augmentor.Pipeline(source_directory=data_fp, output_directory=out_fp)
    aug_pipeline.flip_left_right(probability=0.5)
    num_of_samples = int(1350+600)
    
    aug_pipeline.sample(num_of_samples)

# %%
folder_names = ['cassette_player', 'chain_saw', 'church', 'english_springer', 'french_horn', 'garbage_truck', 'gas_pump', 'golf_ball', 'parachute', 'tench']

# %%
data_dir = "dataset/"
out_dir = os.path.join(os.getcwd(), "dataset_horizontal_flip")

# %%
for folder_name in folder_names:
    augument_horizontal_flip(data_dir=data_dir, label=folder_name, out_dir=out_dir)
# Out:
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/cassette_player.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x160 at 0x7F19B436B070>: 100%|██████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 665.95 Samples/s]
# Initialised with 1250 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/chain_saw.
# Processing <PIL.Image.Image image mode=RGB size=213x160 at 0x7F19B44F68F0>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 654.19 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/church.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=213x160 at 0x7F19B44FA620>: 100%|██████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 663.97 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/english_springer.
# Processing <PIL.Image.Image image mode=RGB size=160x213 at 0x7F19B4520490>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 677.02 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/french_horn.
# Processing <PIL.Image.Image image mode=RGB size=186x160 at 0x7F19B86D6710>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 678.16 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/garbage_truck.
# Processing <PIL.Image.Image image mode=RGB size=213x160 at 0x7F19B45EE020>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 676.09 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/gas_pump.
# Processing <PIL.Image.Image image mode=RGB size=160x240 at 0x7F19B86D5BD0>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 668.57 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/golf_ball.
# Processing <PIL.Image.Image image mode=RGB size=224x160 at 0x7F19B870BB20>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 711.95 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/parachute.
# Processing <PIL.Image.Image image mode=RGB size=213x160 at 0x7F19B44FCE80>: 100%|████████████████████████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 723.43 Samples/s]
# Initialised with 1350 image(s) found.
# Output directory set to /home/sasmi/Desktop/Lakehead University/COMP-5422-FA Comp Vision & Image Analysis/Projects/comp-5422/dataset_horizontal_flip/tench.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x240 at 0x7F19B434F4F0>: 100%|██████████████████████████████████████████████████████████████| 1950/1950 [00:02<00:00, 666.90 Samples/s]

# %% [markdown]
# #### **Mapping the dataset**

# %%
import os
from os import walk

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
current_dir = os.path.abspath(os.getcwd())
data_path = "dataset_horizontal_flip/"
data_mapping = []

for (dirpath, dirnames, filenames) in walk(data_path):
    if filenames:
        label_name = dirpath.split("/")[-1]
        data_full_fp = [os.path.join(current_dir, dirpath, fname) for fname in filenames]
        
        for data_fp in data_full_fp:
            data_mapping.append([data_fp, label_name])

# %%
data_df = pd.DataFrame(data_mapping, columns=["filename", "label"])
data_df.head()
# Out:
#                                             filename      label
# 0  /home/sasmi/Desktop/Lakehead University/COMP-5...  chain_saw
# 1  /home/sasmi/Desktop/Lakehead University/COMP-5...  chain_saw
# 2  /home/sasmi/Desktop/Lakehead University/COMP-5...  chain_saw
# 3  /home/sasmi/Desktop/Lakehead University/COMP-5...  chain_saw
# 4  /home/sasmi/Desktop/Lakehead University/COMP-5...  chain_saw

# %%
labels_map = {
    'cassette_player': 0,
    'chain_saw': 1,
    'church': 2,
    'english_springer': 3,
    'french_horn': 4,
    'garbage_truck': 5,
    'gas_pump': 6,
    'golf_ball': 7,
    'parachute': 8,
    'tench': 9
}

# %%
train, test = train_test_split(data_df, 
                               test_size=0.2, 
                               stratify=data_df["label"], 
                               random_state=42)
print(train.shape)
print(test.shape)
# Out:
# (15600, 2)
# (3900, 2)

# %%
train.to_csv(os.path.join(data_path, "train.csv"), index=False)
test.to_csv(os.path.join(data_path, "test.csv"), index=False)

# %% [markdown]
# #### **Modelling Using the Augmentated Data**

# %%
import os
import pandas as pd
from PIL import Image
from datetime import datetime

import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models

from imgaug import augmenters as iaa

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
class CustomImageDataset(Dataset):
    def __init__(self, annotations_file, labels_map, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_labels['label'] = self.img_labels['label'].map(labels_map)
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = self.img_labels.iloc[idx, 0]
        image = Image.open(img_path).convert('RGB')
        
        label = torch.tensor(int(self.img_labels.iloc[idx, 1]), dtype=torch.uint8)
        
        if self.transform:
            image = self.transform(image)
            
        return image, label

# %%
class ResNetModel(nn.Module):
    def __init__(self, num_classes):
        super(ResNetModel, self).__init__()
        self.resnet18 = models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Linear(in_features=512, out_features=num_classes)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.resnet18(x)

# %%
def create_dir(dir_name):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
        
    else:
        pass

# %%
def dump_model(training_id, model_dir, model):
    model_name = f"{training_id}_resnet18_od.pth"
    create_dir(dir_name=model_dir)
        
    model_dump_fp = os.path.join(model_dir, model_name)
    torch.save(model.state_dict(), model_dump_fp)

# %%
labels_map = {
    'cassette_player': 0,
    'chain_saw': 1,
    'church': 2,
    'english_springer': 3,
    'french_horn': 4,
    'garbage_truck': 5,
    'gas_pump': 6,
    'golf_ball': 7,
    'parachute': 8,
    'tench': 9
}

# %%
train_annotation_fp = "dataset_horizontal_flip/train.csv"
test_annotation_fp = "dataset_horizontal_flip/test.csv"

model_dir = "./models"
training_id = f"horizontal_flip_{datetime.utcnow().timestamp()}"

log_dir = os.path.join("./log_dir", training_id)
create_dir(log_dir)

# %%
# ResNet-18 expects input images of size (224, 224)
feature_transform = transforms.Compose([
    transforms.Resize(size=(224, 224)),
    transforms.ToTensor(),
])

train_dataset = CustomImageDataset(annotations_file=train_annotation_fp, 
                                   labels_map=labels_map,
                                   transform=feature_transform,
                                  )
test_dataset = CustomImageDataset(annotations_file=test_annotation_fp, 
                                  labels_map=labels_map,
                                  transform=feature_transform,
                                 )

# Define the DataLoader
batch_size = 16
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# Display image and label.
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
# Out:
# Feature batch shape: torch.Size([16, 3, 224, 224])
# Labels batch shape: torch.Size([16])

# %%
# Plotting some image samples from the dataloaders
plt.figure(figsize=(10,10))
for i in range(25):
    train_features, train_labels = next(iter(train_dataloader))
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_features[0].numpy().transpose((1, 2, 0)))
    plt.xlabel(train_labels[0].tolist())
plt.show()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
num_class = 10
learning_rate = 1e-03
num_epoch = 20
save_model = True

model = ResNetModel(num_classes=num_class)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# /home/sasmi/anaconda3/envs/jarvis/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/sasmi/anaconda3/envs/jarvis/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
model.train()
model.to(device)

epoch_ls, total_loss, total_accuracy = [], [], []

for epoch in range(num_epoch):

    loss_train, acc_train = 0, 0
    total_samples = 0
    
    for i, data in enumerate(train_dataloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # calculate the loss and accuracy
        loss_train += loss.item()
        
        _, predicted = torch.max(outputs, 1)
        acc_train += (predicted == labels).sum().item()
        total_samples += labels.size(0)
        
        loss.backward()
        optimizer.step()
    
    epoch_loss = loss_train / len(train_dataloader)
    epoch_accuracy = acc_train / total_samples
    
    epoch_ls.append(epoch)
    total_loss.append(epoch_loss)
    total_accuracy.append(epoch_accuracy)
    
    print(f"Current epoch: {epoch} | Training Accuracy: {epoch_accuracy} | Training Loss: {epoch_loss}")
    
if save_model:
    dump_model(training_id, model_dir, model)
# Out:
# Current epoch: 0 | Training Accuracy: 0.41192307692307695 | Training Loss: 1.7118372878661523
# Current epoch: 1 | Training Accuracy: 0.6219871794871795 | Training Loss: 1.1464581892429253
# Current epoch: 2 | Training Accuracy: 0.7121153846153846 | Training Loss: 0.883394876519839
# Current epoch: 3 | Training Accuracy: 0.7657692307692308 | Training Loss: 0.7171309793148285
# Current epoch: 4 | Training Accuracy: 0.8119871794871795 | Training Loss: 0.570489842570745
# Current epoch: 5 | Training Accuracy: 0.8481410256410257 | Training Loss: 0.4621461331500457
# Current epoch: 6 | Training Accuracy: 0.8831410256410256 | Training Loss: 0.358625718553861
# Current epoch: 7 | Training Accuracy: 0.9094871794871795 | Training Loss: 0.2769367275845546
# Current epoch: 8 | Training Accuracy: 0.9342948717948718 | Training Loss: 0.1917013288040956
# Current epoch: 9 | Training Accuracy: 0.948076923076923 | Training Loss: 0.15098639603751973
# Current epoch: 10 | Training Accuracy: 0.9598076923076924 | Training Loss: 0.11701308403188028
# Current epoch: 11 | Training Accuracy: 0.9612820512820512 | Training Loss: 0.11684724100746023
# Current epoch: 12 | Training Accuracy: 0.9705128205128205 | Training Loss: 0.08909613088794197
# Current epoch: 13 | Training Accuracy: 0.9746153846153847 | Training Loss: 0.07617440608828567
# Current epoch: 14 | Training Accuracy: 0.9741666666666666 | Training Loss: 0.07867261596495667
# Current epoch: 15 | Training Accuracy: 0.9775 | Training Loss: 0.06682232888866192
# Current epoch: 16 | Training Accuracy: 0.9791025641025641 | Training Loss: 0.06334894304648818
# Current epoch: 17 | Training Accuracy: 0.9804487179487179 | Training Loss: 0.05631456954985296
# Current epoch: 18 | Training Accuracy: 0.9816666666666667 | Training Loss: 0.05217826594087409
# Current epoch: 19 | Training Accuracy: 0.9864102564102564 | Training Loss: 0.040575679110128805

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in test_dataloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
test_acc = 100 * correct // total
print(f'Test Accuracy: {test_acc}%')
# Out:
# Test Accuracy: 88%

# %%
train_metrics_df = pd.DataFrame(zip(epoch_ls, total_loss, total_accuracy), columns=["epoch", "loss", "accuracy"])
train_metrics_df.to_csv(f"{os.path.join(log_dir, 'training_metrics.csv')}", index=False)
train_metrics_df
# Out:
#     epoch      loss  accuracy
# 0       0  1.711837  0.411923
# 1       1  1.146458  0.621987
# 2       2  0.883395  0.712115
# 3       3  0.717131  0.765769
# 4       4  0.570490  0.811987
# 5       5  0.462146  0.848141
# 6       6  0.358626  0.883141
# 7       7  0.276937  0.909487
# 8       8  0.191701  0.934295
# 9       9  0.150986  0.948077
# 10     10  0.117013  0.959808
# 11     11  0.116847  0.961282
# 12     12  0.089096  0.970513
# 13     13  0.076174  0.974615
# 14     14  0.078673  0.974167
# 15     15  0.066822  0.977500
# 16     16  0.063349  0.979103
# 17     17  0.056315  0.980449
# 18     18  0.052178  0.981667
# 19     19  0.040576  0.986410

# %%
test_acc = 100 * correct // total

# %%
test_metrics_df = pd.DataFrame([test_acc], columns=["accuracy"])
test_metrics_df.to_csv(f"{os.path.join(log_dir, 'test_metrics.csv')}", index=False)
test_metrics_df
# Out:
#    accuracy
# 0        88

# %%
sns.lineplot(data=pd.melt(train_metrics_df, ["epoch"]), x="epoch", y="value", hue="variable")
# Out:
# <Axes: xlabel='epoch', ylabel='value'>

# %% [markdown]
# ### Deprecated Codes

# %%
# img = train_features[0].numpy().transpose((1, 2, 0))
# label = train_labels[0]
# plt.imshow(img)
# plt.show()
# print(f"Label: {label}")
